# %%
import matplotlib.pyplot as pp
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv('./data/AB_NYC_2019.csv', usecols=['id', 'latitude', 'longitude', 'price'])

# %%
data.head()
# Out:
#      id  latitude  longitude  price
# 0  2539  40.64749  -73.97237    149
# 1  2595  40.75362  -73.98377    225
# 2  3647  40.80902  -73.94190    150
# 3  3831  40.68514  -73.95976     89
# 4  5022  40.79851  -73.94399     80

# %%
lat_mid = -73.930045
lon_mid = 40.730999

# %%
nrbins = 700
hist = np.zeros((nrbins,nrbins))

# Compute the histogram with the longitude and latitude data as a source
hist, x_ranges, y_ranges  = np.histogram2d(x=data['latitude'], y=data['longitude'], bins=nrbins, weights=data['price'],
                                          range = [[lon_mid - 0.1, lon_mid + 0.1], [lat_mid - 0.1, lat_mid + 0.1]])

# # We consider the counts on a logarithmic scale
# img = np.log(hist[::-1,:] + 1)

# Plot the counts
pp.figure(figsize=(12,12))
ax = pp.subplot(1,1,1)
pp.imshow(img, 'hot')
pp.axis('off')
# Out:
# (-0.5, 699.5, 699.5, -0.5)

# %%
x_ranges
# Out:
# array([-74.24442   , -74.24388857, -74.24335714, ..., -73.71405286,
#        -73.71352143, -73.71299   ])

# %%
np.mean(x_ranges)
# Out:
# -73.978705

# %%
np.mean(y_ranges)
# Out:
# 40.706425
